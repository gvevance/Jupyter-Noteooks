# %%
from numpy import *

# %%
from pylab import *

# %%
t=linspace(0,20,100000)

# %%
y=0
for n in range(1,100,2):
    #print(n)
    y+=(1/n)*sin(n*t)

# %%
y
# Out:
# array([0.        , 0.00999988, 0.01999842, ..., 0.7871823 , 0.78728535,
#        0.78738762])

# %%
plot(t,y)
